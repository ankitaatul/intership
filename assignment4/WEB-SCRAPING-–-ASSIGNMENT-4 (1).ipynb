# %%
# !pip install selenium
# !pip install bs4
# !pip install requests

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get(" https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Rank_code = []
Name_video = []
Artist_name = []
Upload_date = []
Views_no = []

# %%
Rank_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
for i in Rank_tags[0:30]:
    Rank=i.text
    Rank_code.append(Rank)


Name_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
for i in Name_tags[0:30]:
    Name=i.text
    Name_video.append(Name)
    

Artist_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
for i in Artist_tags[0:30]:
    Artist=i.text
    Artist_name.append(Artist)
    
Upload_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
for i in Upload_tags[0:30]:
    Upload=i.text
    Upload_date.append(Upload)


Views_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
for i in Views_tags[0:30]:
    Views=i.text
    Views_no.append(Views)

# %%
print(len(Rank_code),len(Name_video),len(Artist_name),len(Upload_date),len(Views_no))
# Out:
# 30 30 30 30 30

# %%
df=pd.DataFrame({'Rank_code':Rank_code,'Name_video':Name_video,'Artist_name':Artist_name,'Upload_date':Upload_date,'Views_no':Views_no})
df
# Out:
#    Rank_code                                       Name_video  \
# 0         1.                            "Baby Shark Dance"[3]
# 1         2.                                   "Despacito"[6]
# 2         3.                       "Johny Johny Yes Papa"[12]
# 3         4.                               "Shape of You"[13]
# 4         5.                              "See You Again"[15]
# 5         6.                                  "Bath Song"[20]
# 6         7.                "Phonics Song with Two Words"[21]
# 7         8.                                "Uptown Funk"[22]
# 8         9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9        10.                              "Gangnam Style"[24]
# 10       11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11       12.                          "Wheels on the Bus"[30]
# 12       13.                             "Dame Tu Cosita"[31]
# 13       14.                                      "Sugar"[32]
# ...

# %%
driver.close()

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://www.bcci.tv/")

# %%
fixture=driver.find_element(By.CLASS_NAME,"nav-item")
fixture.click()

# %%
more_fixture=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[2]/div/button")
more_fixture.click()

# %%
Match_title = []
Series_name = []
Place_name = []
Date_id = []
Time_value = []

# %%
title_tags=driver.find_elements(By.XPATH,"//span[@class='matchOrderText ng-binding ng-scope']")
for i in title_tags[0:11]:
    title=i.text
    Match_title.append(title)


Series_tags=driver.find_elements(By.XPATH,"//span[@class='ng-binding']")
for i in Series_tags[0:11]:
    Series=i.text
    Series_name.append(Series)
    

Place_tags=driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']")
for i in Place_tags[0:11]:
    Place=i.text
    Place_name.append(Place)
    
Date_tags=driver.find_elements(By.XPATH,"//h5[@class='ng-binding']")
for i in Date_tags[0:11]:
    Date=i.text
    Date_id.append(Date)


Time_tags=driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']")
for i in Time_tags[0:11]:
    Time=i.text
    Time_value.append(Time)

# %%
print(len(Match_title),len(Series_name),len(Place_name),len(Date_id),len( Time_value))
# Out:
# 11 11 11 11 11

# %%
df=pd.DataFrame({'Match_title':Match_title,'Series_name':Series_name,'Place_name':Place_name,'Date_id':Date_id,'Time_value':Time_value})
df
# Out:
#    Match_title                                    Series_name  \
# 0   1st T20I -                           ASIA CUP WOMENS 2022
# 1   2nd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23
# 2   2nd T20I -                           ASIA CUP WOMENS 2022
# 3   3rd T20I -                           ASIA CUP WOMENS 2022
# 4   3rd T20I -  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022-23
# 5    1st ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
# 6   4th T20I -                           ASIA CUP WOMENS 2022
# 7   5th T20I -                           ASIA CUP WOMENS 2022
# 8    2nd ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
# 9   6th T20I -                           ASIA CUP WOMENS 2022
# 10   3rd ODI -  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23
#
#                                            Place_name      Date_id  \
# 0                       Sylhet Outer Cricket Stadium,   1 OCT 2022
# 1                          Barsapara Cricket Stadium,   2 OCT 2022
# ...

# %%
driver.close()

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://www.guru99.com/")

# %%
Selenium=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
Selenium.send_keys('selenium exception handling')

# %%
search=driver.find_element(By.CLASS_NAME,"gsc-search-button")
search.click()

# %%
EHS=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[6]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a")
EHS.click()

# %%
# window_handles[1] is a second window
driver.switch_to.window(driver.window_handles[1])

# %%
exp_name = []
exp=[]
des=[]

# %%
exp_name=[i.text.split(':') for i in driver.find_elements(By.XPATH,"//div[@class='entry-content single-content']/p")][:40]

for i in exp_name:
    exp.append(i[0])
    des.append(i[1])
df=pd.DataFrame({'Exception name':exp,'Description':des})
df
# Out:
#                              Exception name  \
# 0             1. ElementNotVisibleException
# 1          2. ElementNotSelectableException
# 2                 3. NoSuchElementException
# 3                   4. NoSuchFrameException
# 4                5. NoAlertPresentException
# 5                  6. NoSuchWindowException
# 6         7. StaleElementReferenceException
# 7               8. SessionNotFoundException
# 8                       9. TimeoutException
# 9                    10. WebDriverException
# 10            11. ConnectionClosedException
# 11     12. ElementClickInterceptedException
# 12      13. ElementNotInteractableException
# 13             14. ErrorInResponseException
# 14  15. ErrorHandler.UnknownServerException
# 15         16. ImeActivationFailedException
# 16             17. ImeNotAvailableException
# 17         18. InsecureCertificateException
# 18             19. InvalidArgumentException
# 19         20. InvalidCookieDomainException
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https:/www.billboard.com/")

# %%
hot_100=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[3]/div/nav/ul/li[1]/a")
hot_100.click()

# %%
song=[]

artist=[] 

lwr=[]

pr=[]

wob=[]

song_details=[i.text.split('\n') for i in driver.find_elements(By.XPATH,"//div[@class='o-chart-results-list-row-container']/ul/li[4]")]

for i in song_details:

    song.append(i[0])

    artist.append(i[1])

    lwr.append(i[2])

    pr.append(i[3])

    wob.append(i[4])

# %%
df=pd.DataFrame({'song name':song,'artist name':artist,'last rank':lwr,'peak rank':pr,'weak board':wob})
df
# Out:
#                       song name                     artist name last rank  \
# 0                     As It Was                    Harry Styles         1
# 1                     Bad Habit                      Steve Lacy         2
# 2   I Like You (A Happier Song)  Post Malone Featuring Doja Cat         5
# 3                       Sunroof              Nicky Youre & dazy         4
# 4             Super Freaky Girl                     Nicki Minaj         3
# ..                          ...                             ...       ...
# 95      Thought You Should Know                   Morgan Wallen        98
# 96                Where It Ends                Bailey Zimmerman        93
# 97             Backstage Passes   EST Gee Featuring Jack Harlow         -
# 98                         Snap                       Rosa Linn        97
# 99                Beat The Odds                        Lil Tjay        91
#
#    peak rank weak board
# 0          1         25
# 1          2         12
# ...

# %%
driver.close()

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://github.com/")

# %%
cat_source=driver.find_element(By.XPATH,"//a[@class='mr-lg-3 color-fg-inherit flex-order-2']")
cat_source.click()

# %%
open_source=driver.find_element(By.XPATH,"//ul[@class='d-lg-flex list-style-none']/li[3]/button")
open_source.click()

# %%
trending=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
trending.click()

# %%
Repository_title = []
Repository_description = []
Contributors_count = []
Language_used = []

# %%
time.sleep(1)
#Repository_title
Repository_tags=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']")
for i in Repository_tags[0:22]:
    Repository=i.text
    Repository_title.append(Repository)

time.sleep(1)
#scraping Repository_description
Repository_tags=driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
for i in Repository_tags[0:22]:
    Repository=i.text
    Repository_description.append(Repository)

time.sleep(1)
#scraping Contributors_count
Contributors_tags=driver.find_elements(By.XPATH,'//article[@class="Box-row"]/div[2]/a[2]')
for i in Contributors_tags[0:22]:
    Contributors=i.text
    Contributors_count.append(Contributors)

# %%
time.sleep(1)
#scraping Language_used
Language_tags=driver.find_elements(By.XPATH,"//span[@class='d-inline-block ml-0 mr-3']")
for i in Language_tags[0:22]:
    Language=i.text
    Language_used.append(Language)

# %%
df = pd.DataFrame({'Repository_title':Repository_title,'Repository_description':Repository_description,'Contributors_count':Contributors_count,'Language_used':Language_used})[0:22]
df
# Out:
#                             Repository_title  \
# 0                freeCodeCamp / freeCodeCamp
# 1                TheAlgorithms / C-Plus-Plus
# 2   firstcontributions / first-contributions
# 3                     TheAlgorithms / Python
# 4                     CodeEditApp / CodeEdit
# 5                           TryGhost / Ghost
# 6                            SigNoz / signoz
# 7                            soxoj / maigret
# 8             FernandaCader / recursos-datos
# 9                          ToolJet / ToolJet
# 10                         leeoniya / uFuzzy
# 11                            iced-rs / iced
# 12                             github / docs
# 13            bufbuild / protoc-gen-validate
# 14       stephrobert / awesome-french-devops
# 15                       palera1n / palera1n
# 16                             novuhq / novu
# 17                               odoo / odoo
# 18        lkwq007 / stablediffusion-infinity
# 19                              nvm-sh / nvm
# ...

# %%
driver.close()

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get(" https://www.naukri.com/hr-recruiters-consultants")

# %%
Recruiters =driver.find_element(By.CLASS_NAME,"mTxt")
Recruiters .click()

# %%
Name = []
Designation = []
Company = []
Skills_hire = []
Location = []

# %%
N_tags=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
for i in N_tags[0:45]:
    N=i.text
    Name.append(N)


D_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
for i in D_tags[0:45]:
    D=i.text
    Designation.append(D)
    
    
Skills_tags=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
for i in Skills_tags[0:45]:
    Skills=i.text
    Skills_hire.append(Skills)


L_tags=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
for i in L_tags[0:45]:
    L=i.text
    Location.append(L)

# %%
df = pd.DataFrame({'Name':Name,'Designation':Designation,'Skills_hire':Skills_hire,' Location': Location})[0:10]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_648/899280831.py in <module>
# ----> 1 df = pd.DataFrame({'Name':Name,'Designation':Designation,'Skills_hire':Skills_hire,' Location': Location})[0:10]
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
book_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in book_tags[0:100]:
    book=i.text
    book_name.append(book)


Author_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in Author_tags[0:100]:
    Author=i.text
    Author_name.append(Author)
    

Volumes_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in Volumes_tags[0:100]:
    Volumes=i.text
    Volumes_sold.append(Volumes)
    
Pub_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in Pub_tags[0:100]:
    Pub=i.text
    Publisher.append(Pub)


Gen_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in Gen_tags[0:100]:
    Gen=i.text
    Genre.append(Gen)

# %%
df = pd.DataFrame({'book_name': book_name,'Author_name':Author_name,'Volumes_sold': Volumes_sold,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#                                             book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
naam_tags=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
for i in naam_tags[0:100]:
    naam=i.text
    Name.append(naam)


Year_tags=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
for i in Year_tags[0:100]:
    Year=i.text
    Year_span.append(Year)
    

gen_tags=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in gen_tags[0:100]:
    gen=i.text
    Genre.append(gen)
    
Run_tags=driver.find_elements(By.XPATH,"//span[@class='runtime']")
for i in Run_tags[0:100]:
    Run=i.text
    Run_time.append(Run)


rate_tags=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']")
for i in rate_tags[0:100]:
    rate=i.text
    Ratings.append(rate)
    
Vote_tags=driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p[4]/span[2]")
for i in Vote_tags[0:100]:
    Vote=i.text
    Votes.append(Vote)

# %%
df = pd.DataFrame({'Name': Name,'Year_span':Year_span,'Run_time': Run_time,'Ratings':Ratings,'Votes':Votes,'Genre':Genre})
df
# Out:
#                               Name    Year_span Run_time Ratings      Votes  \
# 0                  Game of Thrones  (2011–2019)   57 min     9.2  2,061,260
# 1                  Stranger Things     (2016– )   51 min     8.7  1,154,850
# 2                 The Walking Dead  (2010–2022)   44 min     8.1    972,277
# 3                   13 Reasons Why  (2017–2020)   60 min     7.5    289,884
# 4                          The 100  (2014–2020)   43 min     7.6    249,316
# ..                             ...          ...      ...     ...        ...
# 95                           Reign  (2013–2017)   42 min     7.4     49,687
# 96  A Series of Unfortunate Events  (2017–2019)   50 min     7.8     60,739
# 97                  Criminal Minds  (2005–2020)   42 min     8.1    195,504
# 98           Scream: The TV Series  (2015–2019)   45 min     7.1     41,149
# 99      The Haunting of Hill House       (2018)  572 min     8.6    238,099
#
#                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By

import time

# %%
# first connect to the browser
driver = webdriver.Chrome(r"C:\Users\Dell\Downloads\chromedriver_win32\chromedriver.exe"  )

# %%
#opening this page from automated chrome browser
driver.get("https://archive.ics.uci.edu/")

# %%
view_all=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]")
view_all.click()

# %%
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_instances = []
No_attribute = []
Year = []

# %%
Dataset_tags=driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
for i in Dataset_tags[0:622]:
    Dataset=i.text
    Dataset_name.append(Dataset)


Data_tags=driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']")
for i in Data_tags[0:500]:
    Data=i.text
    Data_type.append(Data)
    

T_tags=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in T_tags[0:500]:
    T=i.text
    Task.append(T)
    
Attribute_tags=driver.find_elements(By.XPATH,"//span[@class='runtime']")
for i in Attribute_tags[0:500]:
    Attribute=i.text
    Attribute_type.append(Attribute)


instances_tags=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']")
for i in instances_tags[0:500]:
    instances=i.text
    No_instances.append(instances)
    
attribute _tags=driver.find_elements(By.XPATH,"//div[@class='lister-item-content']/p[4]/span[2]")
for i in attribute _tags[0:500]:
    attribute =i.text
    No_attribute s.append(attribute )
    
Y_tags=driver.find_elements(By.XPATH,"//span[@class='genre']")
for i in Y_tags[0:500]:
    Y=i.text
    Year.append(Y)
